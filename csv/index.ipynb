# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
sample_data = pd.read_csv('csv.csv')

# %%
sample_data
# Out:
#                GEO GEOid2                    GEO_display_label  \
# 0               Id    Id2                            Geography
# 1   0500000US42001  42001           Adams County, Pennsylvania
# 2   0500000US42003  42003       Allegheny County, Pennsylvania
# 3   0500000US42005  42005       Armstrong County, Pennsylvania
# 4   0500000US42007  42007          Beaver County, Pennsylvania
# 5   0500000US42009  42009         Bedford County, Pennsylvania
# 6   0500000US42011  42011           Berks County, Pennsylvania
# 7   0500000US42013  42013           Blair County, Pennsylvania
# 8   0500000US42015  42015        Bradford County, Pennsylvania
# 9   0500000US42017  42017           Bucks County, Pennsylvania
# 10  0500000US42019  42019          Butler County, Pennsylvania
# 11  0500000US42021  42021         Cambria County, Pennsylvania
# 12  0500000US42023  42023         Cameron County, Pennsylvania
# 13  0500000US42025  42025          Carbon County, Pennsylvania
# ...

# %%
plt.plot(sample_data.female, "o")
plt.plot(sample_data.male)
plt.show()
